# %% [markdown]
# # Ejercicio 1.
# - Carga en un DataFrame este dataset: https://archive.ics.uci.edu/ml/datasets/Automobile

# %%
import pandas as pd

autos = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", header=None, na_values="?")
autos.columns = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", "body-style", 
              "drive-wheels", "engine-location", "wheel-base", "length", "width", "height", "curb-weight", "engine-type", 
              "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke", "compression-ratio",
              "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"]
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# 2          two    hatchback          rwd           front        94.5   ...
# 3         four        sedan          fwd           front        99.8   ...
# 4         four        sedan          4wd           front        99.4   ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# - Comprueba si tiene datos faltantes y trátalos de la manera que creas más conveniente.

# %%
autos.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
autos = autos.dropna()
autos.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# - Obtén la longitud y anchuras medias por cada categoría (“body-style”).

# %%
grouped_by_body_style = autos[["width", "height", "body-style"]].groupby("body-style")
grouped_by_body_style.mean()
# Out:
#                  width     height
# body-style
# convertible  68.050000  51.900000
# hardtop      66.180000  52.840000
# hatchback    64.889286  52.442857
# sedan        66.067089  54.429114
# wagon        65.382353  56.782353

# %% [markdown]
# - Analiza el atributo peso (“curb-weight”) y dibuja su histograma para apreciar si sigue alguna distribución concreta.

# %%
import matplotlib.pyplot as plt
plt.hist(autos["curb-weight"].values, bins=50 )
# Out:
# (array([ 1.,  0.,  0.,  0.,  1.,  0.,  2.,  7., 12.,  8., 11.,  2.,  8.,
#          6.,  6., 14.,  7., 18.,  7.,  4.,  8.,  2.,  4.,  6.,  5.,  7.,
#          3.,  4.,  5.,  4., 11.,  4.,  4.,  4.,  3.,  1.,  2.,  1.,  2.,
#          2.,  0.,  0.,  1.,  3.,  1.,  0.,  1.,  1.,  0.,  2.]),
#  array([1488.  , 1539.56, 1591.12, 1642.68, 1694.24, 1745.8 , 1797.36,
#         1848.92, 1900.48, 1952.04, 2003.6 , 2055.16, 2106.72, 2158.28,
#         2209.84, 2261.4 , 2312.96, 2364.52, 2416.08, 2467.64, 2519.2 ,
#         2570.76, 2622.32, 2673.88, 2725.44, 2777.  , 2828.56, 2880.12,
#         2931.68, 2983.24, 3034.8 , 3086.36, 3137.92, 3189.48, 3241.04,
#         3292.6 , 3344.16, 3395.72, 3447.28, 3498.84, 3550.4 , 3601.96,
#         3653.52, 3705.08, 3756.64, 3808.2 , 3859.76, 3911.32, 3962.88,
#         4014.44, 4066.  ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# - Analiza cuál es el número de cilindros que se da con más frecuencia en el dataset.

# %%
autos['num-of-cylinders'].mode()
# Out:
# 0    four
# dtype: object

# %% [markdown]
# - Obtén una lista ordenada de las diferentes marcas de coches.

# %%
import numpy as np

autos['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# - ¿Hay alguna variable que puedas utilizar para agrupar diferentes subconjuntos de automóviles para contestar preguntas interesantes sobre relaciones entre variables?

# %%
some_autos = autos.groupby("fuel-type")
some_autos.mean()
# Out:
#            symboling  normalized-losses  wheel-base      length      width  \
# fuel-type
# diesel      0.100000         109.000000  104.390000  182.010000  67.430000
# gas         0.913514         123.308725   98.147568  173.188649  65.743243
#
#               height  curb-weight  engine-size      bore  stroke  \
# fuel-type
# diesel     55.835000  2898.800000   135.700000  3.374500  3.4855
# gas        53.496757  2518.459459   125.956757  3.324807  3.2300
#
#            compression-ratio  horsepower     peak-rpm  city-mpg  highway-mpg  \
# fuel-type
# diesel             22.005000   84.450000  4435.000000  30.30000    34.750000
# gas                 8.860108  106.420765  5200.819672  24.67027    30.318919
#
#                  price
# fuel-type
# diesel     15838.15000
# gas        12916.40884

# %% [markdown]
# Agrupando por tipo de combustible, se puede ver que los coches diesel son más caros y tienen menos potencia, mientras que los coches de gasolina son en media más potentes.

# %% [markdown]
# # Ejercicio 2.
# - Carga en un DataFrame este dataset: https://archive.ics.uci.edu/ml/datasets/Census+Income
# - Estudia si hay variables como el nivel educativo o el país que influyen en que se tuviese un salario mayor o menor de 50K.
#     - Puedes simplemente obtener la cuenta de las veces que sucede una u otra cosa delos diferentes grupos para comenzar, y después utilizar técnicas gráficas, e incluso un contraste de hipótesis.

# %%
adults = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", header=None, na_values=" ?")
adults.columns = ["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", 
                  "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", 
                  "hours-per-week", "native-country", "50K"]

# %%
adults.head(4)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country     50K
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# ...

# %%
adults.dropna()
adults.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# 50K                  0
# dtype: int64

# %%
# %matplotlib inline

grouped_by_country = adults[["native-country", "education", "50K"]].groupby("native-country")
grouped_by_country.apply(lambda x: x["50K"] != "<=50K").groupby("native-country").count()
# Out:
# native-country
#  Cambodia                         19
#  Canada                          121
#  China                            75
#  Columbia                         59
#  Cuba                             95
#  Dominican-Republic               70
#  Ecuador                          28
#  El-Salvador                     106
#  England                          90
#  France                           29
#  Germany                         137
#  Greece                           29
#  Guatemala                        64
#  Haiti                            44
#  Holand-Netherlands                1
#  Honduras                         13
#  Hong                             20
#  Hungary                          13
#  India                           100
#  Iran                             43
#  Ireland                          24
#  Italy                            73
#  Jamaica                          81
#  Japan                            62
#  Laos                             18
# ...

# %%
grouped_by_education = adults[["native-country", "education", "50K"]].groupby(["education"])
grouped_by_education.apply(lambda x: x["50K"] != "<=50K").groupby(["education"]).count()
# Out:
# education
#  10th              933
#  11th             1175
#  12th              433
#  1st-4th           168
#  5th-6th           333
#  7th-8th           646
#  9th               514
#  Assoc-acdm       1067
#  Assoc-voc        1382
#  Bachelors        5355
#  Doctorate         413
#  HS-grad         10501
#  Masters          1723
#  Preschool          51
#  Prof-school       576
#  Some-college     7291
# Name: 50K, dtype: int64

# %%
grouped_by_both = adults[["native-country", "education", "50K"]].groupby(["education", "native-country"])
grouped_by_both.apply(lambda x: x["50K"] != "<=50K").groupby(["native-country", "education"]).count()
# Out:
# native-country  education
#  Cambodia        12th               1
#                  1st-4th            1
#                  7th-8th            1
#                  Bachelors          3
#                  HS-grad            7
#                  Preschool          1
#                  Some-college       5
#  Canada          10th               2
#                  11th               5
#                  12th               2
#                  5th-6th            1
#                  7th-8th            2
#                  9th                3
#                  Assoc-acdm         1
#                  Assoc-voc          7
#                  Bachelors         24
#                  Doctorate          8
#                  HS-grad           31
#                  Masters            8
#                  Prof-school        2
#                  Some-college      25
#  China           10th               3
#                  7th-8th            4
#                  9th                2
# ...
